# %% [markdown]
# ### 랭체인 준비

# %%
# 패키지 설치
# !pip install langchain==0.3.7
# !pip install langchain-google-genai
# !pip install langchain_community
# !pip install langgraph
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.7/408.7 kB 7.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.13
#     Uninstalling langchain-core-0.3.13:
#       Successfully uninstalled langchain-core-0.3.13
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 32.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 44.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.4
#     Uninstalling langchain-0.3.4:
# ...

# %%
import os
from google.colab import userdata

# 환경 변수 준비(좌측 상단의 열쇠 아이콘으로 GOOGLE_API_KEY 설정)
os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

# %% [markdown]
# ### LLM 사용법

# %%
from langchain_google_genai import GoogleGenerativeAI, HarmBlockThreshold, HarmCategory

# LLM 준비
llm = GoogleGenerativeAI(
    model="models/gemini-1.5-flash",  # 모델ID
    temperature=0.3,  # 무작위성
    safety_settings={  # 안전 설정
        HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT : HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT : HarmBlockThreshold.BLOCK_NONE
    },
)

# %%
# LLM 실행
output = llm.invoke("고양이 울음소리를 흉내내보세요.")
print(type(output))
print(output)
# Out:
# <class 'str'>
# 냐옹! 냐아앙! 냐옹냐옹! 냐아아앙!

# %% [markdown]
# # 챗 모델 사용법

# %%
from langchain_google_genai import ChatGoogleGenerativeAI, HarmBlockThreshold, HarmCategory

# 챗 모델 준비
chat_model = ChatGoogleGenerativeAI(
    model="models/gemini-1.5-flash",  # 모델ID
    temperature=0.3,  # 무작위성
    safety_settings={  # 안전 설정
        HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT : HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT : HarmBlockThreshold.BLOCK_NONE
    },
)

# %%
# 챗 모델 실행
messages = [
    ("human", "고양이 울음소리를 흉내내보세요.")
]
output = chat_model.invoke(messages)
print(type(output))
print(output)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# content='냐옹! 냐옹! 냐옹! \n\n고양이 울음소리를 흉내내는 건 꽤 어렵네요. 어떤 종류의 울음소리를 원하시나요? \n\n* **애기 고양이 울음소리:** 냔! 냔! 냔! \n* **화난 고양이 울음소리:** 으르릉! 으르릉! \n* **행복한 고양이 울음소리:** 냐옹~ 냐옹~ \n* **슬픈 고양이 울음소리:** 먕... 먕... \n\n원하는 울음소리에 맞춰서 흉내내 드릴 수 있어요! \n' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-b3dc2b9b-f052-40fb-9c33-7c1fa5d514d6-0' usage_metadata={'input_tokens': 16, 'output_tokens': 179, 'total_tokens': 195, 'input_token_details': {'cache_read': 0}}

# %%
from langchain.schema import HumanMessage

# 메시지를 클래스로 작성
messages = [
    HumanMessage(content="고양이 울음소리를 흉내내보세요.")
]
output = chat_model.invoke(messages)
print(type(output))
print(output)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# content='' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'SAFETY', 'safety_ratings': [{'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'LOW', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'MEDIUM', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-5d0d7928-9285-4322-b433-6ec1747c1634-0' usage_metadata={'input_tokens': 16, 'output_tokens': 0, 'total_tokens': 16, 'input_token_details': {'cache_read': 0}}

# %% [markdown]
# ### 스트리밍

# %%
# LLM 스트리밍
for chunk in llm.stream("Google DeepMind에 관해 알려주세요."):
    print(chunk)
    print("--")
# Out:
# ## Google DeepMind
# --
# : 인공지능의 선두 주자
#
# Google DeepMind는 인공지능
# --
# (AI) 연구 및 개발에 집중하는 영국의 회사로, 2
# --
# 014년 구글에 인수되었습니다.
#
# **주요 특징:**
#
# * **선도적인 AI 연구:** DeepMind는
# --
# 딥러닝, 강화 학습, 일반 인공지능(AGI) 등 다양한 분야에서 혁신적인 연구를 수행
# --
# 합니다.
# * **놀라운 성과:** AlphaGo, AlphaZero, AlphaFold와 같은 획기적인 AI 시스템을 개발하여 바둑, 체스, 단백질 접힘 예측 등 다양한
# --
#  분야에서 인간을 능가하는 성과를 달성했습니다.
# * **다양한 응용 분야:** 의료, 에너지, 과학 등 다양한 분야에서 AI 기술을 활용
# --
# 하여 사회에 기여하고 있습니다.
# * **윤리적 책임:** AI 기술의 윤리적 사용에 대한 책임감을 가지고 있으며, AI 개발과 관련된 윤리적 문제에 대한 연구와 논의를 활발히 진행하고 있습니다.
#
# **주요 연구 분
# --
# 야:**
#
# * **딥러닝:** 인공 신경망을 이용하여 데이터에서 패턴을 학습하고 예측하는 기술
# * **강화 학습:** 환경과 상호 작용하며 보상을 극대화하는 방법을 학습하는 기술
# * **일반 인공
# --
# 지능 (AGI):** 인간과 같은 지능을 가진 AI 시스템을 개발하는 목표
# * **자연어 처리:** 컴퓨터가 인간의 언어를 이해하고 처리하는 기술
# * **컴퓨터 비전:** 컴퓨터가 이미지와 비
# --
# 디오를 이해하고 분석하는 기술
#
# **주요 프로젝트:**
#
# * **AlphaGo:** 바둑 게임에서 인간 프로 기사를 꺾은 AI 시스템
# * **AlphaZero:** 체스, 장기, 바둑 등 다양한 게임에서 인간을 능가하는 AI 시스템
# --
#
# * **AlphaFold:** 단백질 접힘 예측 문제를 해결한 AI 시스템
# ...

# %%
# 챗 모델 스트리밍
messages = [
    ("human", "Google DeepMind에 관해 알려주세요.")
]
for chunk in chat_model.stream(messages):
    print(chunk)
    print("--")
# Out:
# content='## Google DeepMind' additional_kwargs={} response_metadata={'safety_ratings': [{'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-ecbdc6e9-5b4d-40db-9e28-837b38f008c7' usage_metadata={'input_tokens': 12, 'output_tokens': 4, 'total_tokens': 16, 'input_token_details': {'cache_read': 0}}
# --
# ...

# %% [markdown]
# ### 버텍스 AI 제미나이 API의 LLM 사용법

# %%
# 패키지 설치
# !pip install langchain-google-vertexai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 7.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 2.8.0
#     Uninstalling google-cloud-storage-2.8.0:
#       Successfully uninstalled google-cloud-storage-2.8.0
# ...

# %%
from google.colab import userdata
import pathlib
import os
import vertexai

#  환경 변수 준비(좌측 상단의 열쇠 아이콘으로 GOOGLE_APPLICATION_CREDENTIALS 설정)
pathlib.Path("google_application_credentials.json").write_text(
    userdata.get("GOOGLE_APPLICATION_CREDENTIALS"))
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "google_application_credentials.json"

# 버텍스 AI 초기화
vertexai.init()

# %%
from langchain_google_vertexai import VertexAI, HarmBlockThreshold, HarmCategory

# LLM 준비
llm = VertexAI(
    model="models/gemini-1.5-flash-001",  # 모델ID
    temperature=0.3,  # 무작위성
)

# LLM 실행
output = llm.invoke("고양이 울음소리를 흉내내보세요.")
print(type(output))
print(output)
# Out:
# <class 'str'>
# 냐옹! 냐옹냐옹! 냐아아앙! 😹
#
# 어때요? 제 고양이 울음소리 괜찮나요? 😄
#
# 혹시 어떤 종류의 울음소리를 원하시는지 말씀해주시면 더 비슷하게 흉내낼 수 있을 거예요! 예를 들어, 밥 달라고 할 때, 화났을 때, 애정을 갈구할 때 등등... 😊

# %%
from langchain_google_vertexai import ChatVertexAI

# 챗 모델 준비
chat_model = ChatVertexAI(
    model="models/gemini-1.5-flash-001",  # 모델ID
    temperature=0.3,  # 무작위성
)

# 챗 모델 실행
messages = [
    ("human", "고양이 울음소리를 흉내내보세요.")
]
output = chat_model.invoke(messages)
print(type(output))
print(output)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# ...
